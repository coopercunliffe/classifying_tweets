# %% [markdown]
# <a href="https://colab.research.google.com/github/coopercunliffe/springboard/blob/master/word_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS 

pd.set_option('display.max_colwidth', 100)

# %%
df = pd.read_csv('/content/drive/My Drive/twitter data/tweet_df.csv', lineterminator='\n', index_col=0)

# %%
df.shape
# Out:
# (48151, 28)

# %%
df.columns
# Out:
# Index(['source', 'id_str', 'text', 'created_at', 'retweet_count',
#        'in_reply_to_user_id_str', 'favorite_count', 'is_retweet',
#        'created_date', 'created_time', 'created_hour', 'created_hour_est',
#        'is_presidential', 'is_valid', 'created_at_Year', 'created_at_Month',
#        'created_at_Week', 'created_at_Day', 'created_at_Dayofweek',
#        'created_at_Dayofyear', 'created_at_Is_month_end',
#        'created_at_Is_month_start', 'created_at_Is_quarter_end',
#        'created_at_Is_quarter_start', 'created_at_Is_year_end',
#        'created_at_Is_year_start', 'created_atElapsed',
#        'created_at_Dayofweek_str'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                source      id_str  ... created_atElapsed created_at_Dayofweek_str
# 0  Twitter Web Client  1698308935  ...        1241463265                   Monday
#
# [1 rows x 28 columns]

# %%
# trump tweets only, no retweets
trump_df = df[df['is_retweet'] == False]
print(df.shape)
print(trump_df.shape)
print('retweet ratio: ' + str((df.shape[0] - trump_df.shape[0]) / df.shape[0]))
# Out:
# (48151, 28)
# (41921, 28)
# retweet ratio: 0.12938464414030862

# %%
trump_df.iloc[0]
# Out:
# source                                                                                                          Twitter Web Client
# id_str                                                                                                                  1698308935
# text                           Be sure to tune in and watch Donald Trump on Late Night with David Letterman as he presents the ...
# created_at                                                                                               2009-05-04 18:54:25+00:00
# retweet_count                                                                                                                  253
# in_reply_to_user_id_str                                                                                                        NaN
# favorite_count                                                                                                                 202
# is_retweet                                                                                                                   False
# created_date                                                                                                            2009-05-04
# created_time                                                                                                              18:54:25
# created_hour                                                                                                                    18
# created_hour_est                                                                                                                14
# is_presidential                                                                                                              False
# is_valid                                                                                                                     False
# created_at_Year                                                                                                               2009
# created_at_Month                                                                                                                 5
# created_at_Week                                                                                                                 19
# created_at_Day                                                                                                                   4
# created_at_Dayofweek                                                                                                             0
# created_at_Dayofyear                                                                                                           124
# created_at_Is_month_end                                                                                                      False
# created_at_Is_month_start                                                                                                    False
# created_at_Is_quarter_end                                                                                                    False
# created_at_Is_quarter_start                                                                                                  False
# created_at_Is_year_end                                                                                                       False
# created_at_Is_year_start                                                                                                     False
# created_atElapsed                                                                                                       1241463265
# created_at_Dayofweek_str                                                                                                    Monday
# Name: 0, dtype: object

# %%
type(trump_df['created_at'][0])
# Out:
# str

# %%
candidate_df = trump_df[trump_df['is_presidential'] == False]
president_df = trump_df[trump_df['is_presidential'] == True]

# %%
candidate_df.shape
# Out:
# (30136, 28)

# %%
president_df.shape
# Out:
# (11785, 28)

# %%
def plot_wordcloud(df):

  comment_words = '' 
  stopwords = set(STOPWORDS)
  stopwords.update(['realdonaldtrump', 'https',
                    'will', 'co', 'amp', 'rt'])

  for val in df['text']: 
        
      # typecaste each val to string 
      val = str(val) 
    
      # split the value 
      tokens = val.split() 
        
      # Converts each token into lowercase 
      for i in range(len(tokens)): 
          tokens[i] = tokens[i].lower() 
        
      comment_words += " ".join(tokens)+" "

  wordcloud = WordCloud(width = 800, height = 800, 
                  background_color ='white', 
                  stopwords = stopwords, 
                  min_font_size = 10).generate(comment_words)
                  
  plt.figure(figsize = (8, 8), facecolor = None) 
  plt.imshow(wordcloud) 
  plt.axis("off") 
  plt.tight_layout(pad = 0) 
    
  plt.show()

# %%
plot_wordcloud(trump_df)

# %%
plot_wordcloud(candidate_df)

# %%
plot_wordcloud(president_df)

# %%
df[df['created_date'] == '2019-11-08']
# Out:
#                    source  ...  created_at_Dayofweek_str
# 42353  Twitter for iPhone  ...                    Friday
# 42354  Twitter for iPhone  ...                    Friday
# 42355  Twitter for iPhone  ...                    Friday
# 42356  Twitter for iPhone  ...                    Friday
# 42357  Twitter for iPhone  ...                    Friday
# 42358  Twitter for iPhone  ...                    Friday
#
# [6 rows x 28 columns]

# %%
tweets_by_day = pd.DataFrame(df['created_date'].value_counts().sort_index())
tweets_by_day = tweets_by_day.rename(columns={'created_date':'total number of tweets'})
tweets_by_day['retweets'] = [df[(df['created_date'] == i) & (df['is_retweet'] == True)].shape[0] for i in tweets_by_day.index]
print(tweets_by_day.iloc[-220:-170])
tweets_by_day.plot(figsize=(15,6), title="Tweets per Day")
plt.show()
# Out:
#             total number of tweets  retweets
# 2019-10-05                      45        15
# 2019-10-06                      44        19
# 2019-10-07                      26         6
# 2019-10-08                      51        29
# 2019-10-09                      49        13
# 2019-10-10                      24         4
# 2019-10-11                      52        31
# 2019-10-12                      28        10
# 2019-10-13                      24         4
# 2019-10-14                      34         3
# 2019-10-15                      15         0
# 2019-10-16                      25         6
# 2019-10-17                      32        14
# 2019-10-18                      22         5
# 2019-10-19                      55        35
# 2019-10-20                      22         5
# 2019-10-21                      18         6
# 2019-10-22                      41        27
# 2019-10-23                      47        25
# 2019-10-24                      15         6
# 2019-10-25                      42        24
# 2019-10-26                      36        12
# 2019-10-27                       7         2
# 2019-10-28                      14         8
# 2019-10-29                      48        30
# 2019-10-30                      34        15
# 2019-10-31                      37        20
# 2019-11-01                      37         4
# 2019-11-02                      35        27
# 2019-11-03                      24         5
# 2019-11-04                      38        15
# 2019-11-05                      40        24
# 2019-11-06                      23         7
# 2019-11-07                      19         3
# 2019-11-08                       6         3
# 2019-11-09                      44        32
# 2019-11-10                      51        33
# 2019-11-11                      38        15
# 2019-11-12                      14         4
# 2019-11-13                      43        30
# 2019-11-14                      34        21
# 2019-11-15                      43        24
# 2019-11-16                      25        11
# 2019-11-17                      51        15
# 2019-11-18                      14         1
# 2019-11-19                      38        32
# 2019-11-20                      37        21
# 2019-11-21                      35        12
# 2019-11-22                      30        16
# 2019-11-23                      17         4

# %%
df[(df['created_at_Year'] == 2018) & (df['is_retweet'] == True)].shape
# Out:
# (464, 28)

# %%
tweets_by_day.head()
# Out:
#             total number of tweets  retweets
# 2009-05-04                       1         0
# 2009-05-05                       1         0
# 2009-05-08                       2         0
# 2009-05-12                       2         0
# 2009-05-13                       1         0

# %%
tweets_by_day.sort_values('total number of tweets')
# Out:
#             total number of tweets  retweets
# 2009-05-04                       1         0
# 2017-08-20                       1         0
# 2011-03-03                       1         0
# 2011-03-04                       1         0
# 2017-07-30                       1         0
# ...                            ...       ...
# 2020-05-10                     109        86
# 2019-12-12                     112        89
# 2015-01-06                     118         0
# 2020-01-22                     144       126
# 2015-01-05                     160         0
#
# [3252 rows x 2 columns]

# %%
max_tweet_day = trump_df[trump_df['created_date'] == '2015-01-05']

# %%
max_tweet_day['text'].head()
# Out:
# 18560                           In less than 30 minutes- watch the season premiere of @ApprenticeNBC on NBC.
# 18561             This is going to be a special season - truly great characters and cast. You will soon see!
# 18562                 "@MLRatchford: @ApprenticeNBC @realDonaldTrump rooting for @RealGilbert. #TeamGilbert"
# 18563             "@fabiolasellsnj: @DonaldJTrumpJr @realDonaldTrump @ApprenticeNBC looking forward to this"
# 18564    "@Flowerchic462: Ok Tweeps. Who is going home first tonight?! #CelebApprentice @ApprenticeNBC @r...
# Name: text, dtype: object

# %%
max_tweet_day['text']
# Out:
# 18560                           In less than 30 minutes- watch the season premiere of @ApprenticeNBC on NBC.
# 18561             This is going to be a special season - truly great characters and cast. You will soon see!
# 18562                 "@MLRatchford: @ApprenticeNBC @realDonaldTrump rooting for @RealGilbert. #TeamGilbert"
# 18563             "@fabiolasellsnj: @DonaldJTrumpJr @realDonaldTrump @ApprenticeNBC looking forward to this"
# 18564    "@Flowerchic462: Ok Tweeps. Who is going home first tonight?! #CelebApprentice @ApprenticeNBC @r...
#                                                         ...
# 18715                    "@mccull0817: @realDonaldTrump @ShawnJohnson calls the show evil and that is FUN??"
# 18716    "@ShinySheet:Olympic gold medalist wins Trump Invitational Grand Prix at @realDonaldTrump's Mar-...
# 18717    "@MindOfMcN: @Chrisgraham101 RT  TTonight the 2nd and 3rd eps of The Apprentice are on at 8 &amp...
# 18718    Looking forward to speaking at @Citizens_United &amp; @SteveKingIA’s “Iowa’s Freedom Summit” on ...
# 18719          Via @feminamissindia: “@MannyPacquiao among @MissUniverse 2015 judges” http://t.co/69Br0Caoee
# Name: text, Length: 160, dtype: object

# %%
tweets_by_hour = pd.DataFrame(trump_df['created_hour_est'].value_counts().sort_index())

# %%
tweets_by_hour
# Out:
#     created_hour_est
# 0                964
# 1                605
# 2                395
# 3                315
# 4                414
# 5                537
# 6               1165
# 7               2012
# 8               2499
# 9               2546
# 10              2353
# 11              2273
# 12              2137
# 13              1912
# 14              2460
# 15              2909
# 16              3151
# 17              2328
# 18              1732
# 19              1685
# 20              1779
# 21              1947
# 22              2084
# 23              1719

# %%
tweets_by_hour = tweets_by_hour.rename(columns={'created_hour_est':'total number of tweets'})

tweets_by_hour.plot(kind = 'bar', figsize=(20,6), title='Tweets by Hour of the Day (EST)')

# %%
tweets_by_year = pd.DataFrame(trump_df['created_at_Year'].value_counts().sort_index())
tweets_by_year.plot(kind = 'bar', figsize=(20,6))

# %%
trump_df.iloc[40000]
# Out:
# source                                                       Twitter for iPhone
# id_str                                                      1207982039934345216
# text                           Thank you Bill. So true! https://t.co/BaMNE4TXdU
# created_at                                            2019-12-20 11:12:16+00:00
# retweet_count                                                             10295
# in_reply_to_user_id_str                                                     NaN
# favorite_count                                                            46089
# is_retweet                                                                False
# created_date                                                         2019-12-20
# created_time                                                           11:12:16
# created_hour                                                                 11
# created_hour_est                                                              7
# is_presidential                                                            True
# is_valid                                                                  False
# created_at_Year                                                            2019
# created_at_Month                                                             12
# created_at_Week                                                              51
# created_at_Day                                                               20
# created_at_Dayofweek                                                          4
# created_at_Dayofyear                                                        354
# created_at_Is_month_end                                                   False
# created_at_Is_month_start                                                 False
# created_at_Is_quarter_end                                                 False
# created_at_Is_quarter_start                                               False
# created_at_Is_year_end                                                    False
# created_at_Is_year_start                                                  False
# created_atElapsed                                                    1576840336
# created_at_Dayofweek_str                                                 Friday
# Name: 43863, dtype: object

# %%
tweets_by_month = pd.DataFrame(trump_df['created_at_Month'].value_counts().sort_index())

tweets_by_month = tweets_by_month.rename(columns={'created_at_Month':'total number of tweets'})

tweets_by_month.plot(kind = 'bar', figsize=(15,6), title='Tweets by Month')

# %%
election_years = trump_df[(trump_df['created_at_Year'] == 2012) | (trump_df['created_at_Year'] == 2016)]

# %%
election_years.shape
# Out:
# (7568, 28)

# %%
tweets_by_month_election_years = pd.DataFrame(election_years['created_at_Month'].value_counts().sort_index())

tweets_by_month_election_years = tweets_by_month_election_years.rename(columns={'created_at_Month':'total number of tweets'})

tweets_by_month_election_years.plot(kind = 'bar', figsize=(15,6), title='Tweets by Month: 2012 and 2016')

# %%
tweets_by_dayofweek = pd.DataFrame(trump_df['created_at_Dayofweek_str'].value_counts().sort_index())

tweets_by_dayofweek = tweets_by_dayofweek.rename(columns={'created_at_Dayofweek_str':'total number of tweets'})

tweets_by_dayofweek['day_int'] = [4, 0, 5, 6, 3, 1, 2]

tweets_by_dayofweek = tweets_by_dayofweek.sort_values('day_int')

tweets_by_dayofweek = tweets_by_dayofweek[['total number of tweets']]

tweets_by_dayofweek.plot(kind = 'bar', title='Total Tweets by Day of the Week', figsize=(15,6))

plt.show()

# %%
trump_df.iloc[0]
# Out:
# source                                                                                                          Twitter Web Client
# id_str                                                                                                                  1698308935
# text                           Be sure to tune in and watch Donald Trump on Late Night with David Letterman as he presents the ...
# created_at                                                                                               2009-05-04 18:54:25+00:00
# retweet_count                                                                                                                  253
# in_reply_to_user_id_str                                                                                                        NaN
# favorite_count                                                                                                                 202
# is_retweet                                                                                                                   False
# created_date                                                                                                            2009-05-04
# created_time                                                                                                              18:54:25
# created_hour                                                                                                                    18
# created_hour_est                                                                                                                14
# is_presidential                                                                                                              False
# is_valid                                                                                                                     False
# created_at_Year                                                                                                               2009
# created_at_Month                                                                                                                 5
# created_at_Week                                                                                                                 19
# created_at_Day                                                                                                                   4
# created_at_Dayofweek                                                                                                             0
# created_at_Dayofyear                                                                                                           124
# created_at_Is_month_end                                                                                                      False
# created_at_Is_month_start                                                                                                    False
# created_at_Is_quarter_end                                                                                                    False
# created_at_Is_quarter_start                                                                                                  False
# created_at_Is_year_end                                                                                                       False
# created_at_Is_year_start                                                                                                     False
# created_atElapsed                                                                                                       1241463265
# created_at_Dayofweek_str                                                                                                    Monday
# Name: 0, dtype: object

# %%
violin_df = trump_df[['created_at_Dayofweek', 'created_at_Dayofweek_str',
                      'created_hour_est', 'is_presidential']]

violin_df['yes_no'] = ['After Inauguration' if i == True 
                       else 'Before Inauguration' for i in violin_df['is_presidential']]

violin_df = violin_df.rename(columns={'yes_no':'After Inauguration Day'})

sns.set(rc={'figure.figsize':(15, 8)})

ax = sns.violinplot(x='created_at_Dayofweek_str', y='created_hour_est', hue='After Inauguration Day',
                    data=violin_df.sort_values('created_at_Dayofweek'), palette='muted', split=True)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

ax.set(xlabel='', ylabel='Hour of the Day Tweet was Created', 
       title='President Trump\'s Daily Tweet Schedule Before and After his Inauguration')



plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
trump_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41921 entries, 0 to 48150
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   source                       41921 non-null  object
#  1   id_str                       41921 non-null  int64
#  2   text                         41921 non-null  object
#  3   created_at                   41921 non-null  object
#  4   retweet_count                41921 non-null  int64
#  5   in_reply_to_user_id_str      3301 non-null   float64
#  6   favorite_count               41921 non-null  int64
#  7   is_retweet                   41921 non-null  bool
#  8   created_date                 41921 non-null  object
#  9   created_time                 41921 non-null  object
#  10  created_hour                 41921 non-null  int64
#  11  created_hour_est             41921 non-null  int64
#  12  is_presidential              41921 non-null  bool
#  13  is_valid                     41921 non-null  bool
#  14  created_at_Year              41921 non-null  int64
#  15  created_at_Month             41921 non-null  int64
#  16  created_at_Week              41921 non-null  int64
#  17  created_at_Day               41921 non-null  int64
#  18  created_at_Dayofweek         41921 non-null  int64
#  19  created_at_Dayofyear         41921 non-null  int64
#  20  created_at_Is_month_end      41921 non-null  bool
#  21  created_at_Is_month_start    41921 non-null  bool
#  22  created_at_Is_quarter_end    41921 non-null  bool
#  23  created_at_Is_quarter_start  41921 non-null  bool
#  24  created_at_Is_year_end       41921 non-null  bool
#  25  created_at_Is_year_start     41921 non-null  bool
#  26  created_atElapsed            41921 non-null  int64
#  27  created_at_Dayofweek_str     41921 non-null  object
# dtypes: bool(9), float64(1), int64(12), object(6)
# memory usage: 8.0+ MB

# %%
violin_df = trump_df[trump_df['created_at_Year'].isin([2016, 2017])][['created_at_Dayofweek',
                                                                 'created_at_Dayofweek_str',
                                                                 'created_hour_est', 
                                                                 'is_presidential']]


violin_df['yes_no'] = ['After Inauguration' if i == True 
                       else 'Before Inauguration' for i in violin_df['is_presidential']]

violin_df = violin_df.rename(columns={'yes_no':'After Inauguration Day'})

sns.set(rc={'figure.figsize':(15, 8)})

ax = sns.violinplot(x='created_at_Dayofweek_str', y='created_hour_est', hue='After Inauguration Day',
                    data=violin_df.sort_values('created_at_Dayofweek'), palette='muted', split=True)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

ax.set(xlabel='', ylabel='Hour of the Day Tweet was Created', 
       title='President Trump\'s Daily Tweet Schedule Before and After his Inauguration')



plt.show()
# Out:
# (6329, 4)

# %%
from PIL import Image

# %%
for i in range(2009, 2021):
  print(i)
# Out:
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
def make_violin(df, year):

  violin_df = df[df['created_at_Year'].isin([year, year+1])][['created_at_Dayofweek',
                                                              'created_at_Dayofweek_str',
                                                              'created_hour_est', 
                                                              'is_presidential',
                                                              'created_at_Year']]

  violin_df['yes_no'] = [str(year) if i == year 
                        else str(year+1) for i in violin_df['created_at_Year']]

  violin_df = violin_df.rename(columns={'yes_no':'After Inauguration Day'})

  sns.set(rc={'figure.figsize':(15, 8)})

  ax = sns.violinplot(x='created_at_Dayofweek_str', y='created_hour_est', hue='After Inauguration Day',
                      data=violin_df.sort_values('created_at_Dayofweek'), palette='muted', split=True)

  plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

  ax.set(xlabel='', ylabel='Hour of the Day Tweet was Created', 
        title='President Trump\'s Daily Tweet Schedule Year to Year')

  plt.savefig('/content/drive/My Drive/twitter data/violin_images/' + str(year) + '.png')

  plt.clf()

  # plt.show()

# %%
for i in range(2012, 2020):
  make_violin(trump_df, i)

# %%
images = []

for i in range(2012, 2020):
  img = Image.open('/content/drive/My Drive/twitter data/violin_images/' + str(i) + '.png')
  images.append(img)

# %%
len(images)
# Out:
# 8

# %%
images[0].save('/content/drive/My Drive/twitter data/violin_images/violin_gif.gif',
               save_all=True, append_images=images[1:], optimize=False, duration=3000, loop=0)

# %%
trump_df.iloc[0]
# Out:
# source                                                                                                          Twitter Web Client
# id_str                                                                                                                  1698308935
# text                           Be sure to tune in and watch Donald Trump on Late Night with David Letterman as he presents the ...
# created_at                                                                                               2009-05-04 18:54:25+00:00
# retweet_count                                                                                                                  253
# in_reply_to_user_id_str                                                                                                        NaN
# favorite_count                                                                                                                 202
# is_retweet                                                                                                                   False
# created_date                                                                                                            2009-05-04
# created_time                                                                                                              18:54:25
# created_hour                                                                                                                    18
# created_hour_est                                                                                                                14
# is_presidential                                                                                                              False
# is_valid                                                                                                                     False
# created_at_Year                                                                                                               2009
# created_at_Month                                                                                                                 5
# created_at_Week                                                                                                                 19
# created_at_Day                                                                                                                   4
# created_at_Dayofweek                                                                                                             0
# created_at_Dayofyear                                                                                                           124
# created_at_Is_month_end                                                                                                      False
# created_at_Is_month_start                                                                                                    False
# created_at_Is_quarter_end                                                                                                    False
# created_at_Is_quarter_start                                                                                                  False
# created_at_Is_year_end                                                                                                       False
# created_at_Is_year_start                                                                                                     False
# created_atElapsed                                                                                                       1241463265
# created_at_Dayofweek_str                                                                                                    Monday
# Name: 0, dtype: object

# %%
trump_df.set_index('created_at').plot(y=['retweet_count'], figsize=(20,6))

# Aggregate per day

# %%
# Most retweeted all-time

trump_df.sort_values('retweet_count').iloc[-1]['text']
# Out:
# '#FraudNewsCNN #FNN https://t.co/WYUnHjjUjg'

# %%
trump_df.set_index('created_at').plot(y=['favorite_count'], figsize=(20,6))

# aggregate this by day

# %%
# Most favorited all time
trump_df.sort_values('favorite_count').iloc[-1]['text']
# Out:
# 'A$AP Rocky released from prison and on his way home to the United States from Sweden. It was a Rocky Week, get home ASAP A$AP!'

# %%
announcement = trump_df[trump_df['created_date'] == '2015-06-16']

# %%
announcement.shape
# Out:
# (30, 28)

# %%
announcement.text
# Out:
# 22156    "@realJoeMurray: Hopefully tomorrow is the day we start to make America great again! Looking for...
# 22157    "@brentcfritz: Today is the day America becomes great again. @realDonaldTrump has some huge news...
# 22158    "@insuraider: @realDonaldTrump is going to make Hillary's head spin tomorrow morning. Presidenti...
# 22159                                        "@DONJUBBER: @realDonaldTrump Shock the world!#Trump4President"
# 22160    "@PianoBecca: @realDonaldTrump No Amercian, really, can impact such staggering influence. Stay T...
# 22161    "@isabelsimon80: @realDonaldTrump @brentcfritz Donald has as good of a chance as anyone else.. 👍...
# 22162    "@Knight276: @realDonaldTrump @realJoeMurray America can be great again with trump at the helm. ...
# 22163    "@_Snurk: @realDonaldTrump Love it! Always respect FIGHTERS over overrated loser POLITITIANS!! I...
# 22164    "@rg_radical99: Counting down the hours to @realDonaldTrump announcement! Ready for America to b...
# 22165    "@Rhumeey: I really would want to see what America would look like...with @realDonaldTrump at th...
# 22166                                           "@NickyFlash2: #Trump4President #Trump2016 @realDonaldTrump"
# 22167    "@Jarod_Pitmon10: I am a full supporter of #Trump2016 @realDonaldTrump is a guy that will help t...
# 22168                             "@premuse: @realDonaldTrump Let's take this country back. #TrumpLeeds2016"
# 22169    "@Desheay: @realDonaldTrump Your twitter banner is awesome. Cant wait for tomorrow.....TRUMP 201...
# 22170                              "@DavidSBaldwin: @realDonaldTrump today's the day #Trump2016! Good luck!"
# 22171    "@jaketapper: DonaldTrump in Iowa says "I have a Gucci store that's worth more money than Romney...
# 22172    Big time in U.S. today - MAKE AMERICA GREAT AGAIN! Politicians are all talk and no action - they...
# 22173                                                                        Thanks. https://t.co/eZfgrOy1Hn
# 22174    "@AppSame We are going to listen @realDonaldTrump If you are really running &amp; if you keep to...
# 22175    It is almost time. I will be making a major announcement from @TrumpTowerNY at 11AM. Follow on s...
# 22176                                          Make sure to follow me on @periscopeco #MakeAmericaGreatAgain
# 22177    In one hour I will be making a major announcement from Trump Tower. Watch it live on Periscope! ...
# 22178                   Make sure to follow me on @periscopeco. I will be streaming my announcement at 11AM.
# 22179                                                    11AM #MakeAmericaGreatAgain https://t.co/445bOdp6QY
# 22180                                             Thanks Geraldo, you're a champion. https://t.co/APfc0PThCP
# 22181                 LIVE on #Periscope: Major announcement! #MakeAmericaGreatAgain https://t.co/XW3PqHemNq
# 22182    I am officially running for President of the United States. #MakeAmericaGreatAgain https://t.co/...
# 22183                                                         #MakeAmericaGreatAgain https://t.co/JguVmqXqWA
# 22184                                                                   Thanks Eric. https://t.co/phUbaTvq8d
# 22185    Today I officially declared my candidacy for President of the United States. Watch the video of ...
# Name: text, dtype: object

# %%
trump_df.loc[22182]
# Out:
# source                                                                                                                   Instagram
# id_str                                                                                                          610838591242137600
# text                           I am officially running for President of the United States. #MakeAmericaGreatAgain https://t.co/...
# created_at                                                                                               2015-06-16 15:57:23+00:00
# retweet_count                                                                                                                11230
# in_reply_to_user_id_str                                                                                                        NaN
# favorite_count                                                                                                               10400
# is_retweet                                                                                                                   False
# created_date                                                                                                            2015-06-16
# created_time                                                                                                              15:57:23
# created_hour                                                                                                                    15
# created_hour_est                                                                                                                11
# is_presidential                                                                                                              False
# is_valid                                                                                                                     False
# created_at_Year                                                                                                               2015
# created_at_Month                                                                                                                 6
# created_at_Week                                                                                                                 25
# created_at_Day                                                                                                                  16
# created_at_Dayofweek                                                                                                             1
# created_at_Dayofyear                                                                                                           167
# created_at_Is_month_end                                                                                                      False
# created_at_Is_month_start                                                                                                    False
# created_at_Is_quarter_end                                                                                                    False
# created_at_Is_quarter_start                                                                                                  False
# created_at_Is_year_end                                                                                                       False
# created_at_Is_year_start                                                                                                     False
# created_atElapsed                                                                                                       1434470243
# created_at_Dayofweek_str                                                                                                   Tuesday
# Name: 22182, dtype: object
